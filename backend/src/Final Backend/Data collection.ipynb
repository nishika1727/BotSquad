# %%
import pdfplumber
import os
import json

def extract_pdf_to_json(pdf_path):
    data = {
        "pdf_file": os.path.basename(pdf_path),
        "content": []
    }

    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            page_text = page.extract_text() or ""
            tables = page.extract_tables()
            table_data = []
            for table in tables:
                table_data.append(table)

            data["content"].append({
                "page_number": page.page_number,
                "text": page_text.strip(),
                "tables": table_data
            })

    return data

def extract_all_pdfs_to_json(pdf_folder, output_json="pdf_data.json"):
    all_data = []
    for file in os.listdir(pdf_folder):
        if file.lower().endswith(".pdf"):
            full_path = os.path.join(pdf_folder, file)
            print(f"Processing {file}...")
            result = extract_pdf_to_json(full_path)
            all_data.append(result)

    with open(output_json, "w", encoding="utf-8") as f:
        json.dump(all_data, f, indent=2, ensure_ascii=False)
    print(f"\n✅ Data saved to: {output_json}")


extract_all_pdfs_to_json("PDFs/")
# Out:
# Processing handbook.pdf...
# Processing handbook_c.pdf...
# Processing hbi-2025-faculty-of-arts.pdf...
# Processing hbi-2025-faculty-of-business.pdf...
# Cannot set gray non-stroke color because /'Pattern1' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern2' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern3' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern4' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern5' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern6' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern7' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern8' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern9' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern10' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern11' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern12' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern13' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern14' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern15' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern16' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern17' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern18' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern19' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern20' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern21' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern22' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern23' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern1' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern2' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern3' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern4' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern5' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern6' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern7' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern8' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern9' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern10' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern11' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern12' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern13' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern14' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern15' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern16' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern17' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern18' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern19' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern1' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern2' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern3' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern4' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern5' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern6' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern7' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern8' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern9' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern10' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern11' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern12' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern13' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern14' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern15' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern16' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern17' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern18' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern19' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern20' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern21' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern22' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern23' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern24' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern25' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern26' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern27' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern28' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern29' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern30' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern31' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern32' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern33' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern34' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern35' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern36' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern37' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern38' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern39' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern40' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern41' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern42' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern43' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern44' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern45' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern1' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern2' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern3' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern4' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern5' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern6' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern7' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern8' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern9' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern10' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern11' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern12' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern13' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern14' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern15' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern16' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern17' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern18' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern19' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern20' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern1' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern2' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern3' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern4' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern5' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern6' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern7' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern8' is an invalid float value
# Cannot set gray non-stroke color because /'Pattern9' is an invalid float value
# Processing hbi-2025-faculty-of-design-fine-arts.pdf...
# Processing hbi-2025-faculty-of-education.pdf...
# Processing hbi-2025-faculty-of-engineering.pdf...
# Processing hbi-2025-faculty-of-laws.pdf...
# Processing hbi-2025-faculty-of-medical-science.pdf...
# Processing hbi-2025-faculty-of-pharmacy.pdf...
# Processing hbi-2025-faculty-of-science.pdf...
# Processing hbi-2025-final-faculty-of-languages.pdf...
# Processing hbi-2025-multi-faculty-depts.pdf...
#
# ✅ Data saved to: pdf_data.json

# %%
import pandas as pd
import json

# Load the JSON file
with open("pdf_data.json", "r", encoding="utf-8") as f:
    raw_data = json.load(f)

# Flatten into rows per page
records = []
for doc in raw_data:
    for page in doc["content"]:
        records.append({
            "pdf_file": doc["pdf_file"],
            "page_number": page["page_number"],
            "text": page.get("text", "").strip(),
            "tables": page.get("tables", [])
        })

df = pd.DataFrame(records)

# %%
df.shape
# Out:
# (363, 4)

# %%
df
# Out:
#                              pdf_file  page_number  \
# 0                        handbook.pdf            1
# 1                        handbook.pdf            2
# 2                        handbook.pdf            3
# 3                        handbook.pdf            4
# 4                        handbook.pdf            5
# ..                                ...          ...
# 358  hbi-2025-multi-faculty-depts.pdf           20
# 359  hbi-2025-multi-faculty-depts.pdf           21
# 360  hbi-2025-multi-faculty-depts.pdf           22
# 361  hbi-2025-multi-faculty-depts.pdf           23
# 362  hbi-2025-multi-faculty-depts.pdf           24
#
#                                                   text  \
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025\nHo...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025\nVi...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025\nPA...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025\nOF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025\nTA...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
#                                                 tables
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 358  [[[Choice Based Physics Course + Practical, Ob...
# 359  [[[Course, Seats, Duration, Eligibility*, Admi...
# 360  [[[Semester-I, Semester-II], [English-I, Engli...
# 361  [[[Paper IV & V-\n(a) Information Technology A...
# 362  [[[, , , Panjab University Chandigarh as equiv...
#
# [363 rows x 4 columns]

# %%
import neattext.functions as nfx
import re

def clean_text(x):
    if not isinstance(x, str):
        return ""
    x = nfx.remove_multiple_spaces(x)
    x = re.sub(r'\s+', ' ', re.sub(r'[^A-Za-z0-9\-\(\)\s]', ' ', x))
    return x.strip()

# %%
df['cleaned_text'] = df['text'].apply(clean_text)

# %%
df
# Out:
#                              pdf_file  page_number  \
# 0                        handbook.pdf            1
# 1                        handbook.pdf            2
# 2                        handbook.pdf            3
# 3                        handbook.pdf            4
# 4                        handbook.pdf            5
# ..                                ...          ...
# 358  hbi-2025-multi-faculty-depts.pdf           20
# 359  hbi-2025-multi-faculty-depts.pdf           21
# 360  hbi-2025-multi-faculty-depts.pdf           22
# 361  hbi-2025-multi-faculty-depts.pdf           23
# 362  hbi-2025-multi-faculty-depts.pdf           24
#
#                                                   text  \
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025\nHo...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025\nVi...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025\nPA...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025\nOF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025\nTA...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
#                                                 tables  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 358  [[[Choice Based Physics Course + Practical, Ob...
# 359  [[[Course, Seats, Duration, Eligibility*, Admi...
# 360  [[[Semester-I, Semester-II], [English-I, Engli...
# 361  [[[Paper IV & V-\n(a) Information Technology A...
# 362  [[[, , , Panjab University Chandigarh as equiv...
#
#                                           cleaned_text
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025 Hon...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025 Vic...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025 PAN...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025 OFF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025 TAB...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
# [363 rows x 5 columns]

# %%
def flatten_tables_verbose(tables):
    if not tables or not isinstance(tables, list):
        return ""
    
    flat = []
    for table in tables:
        if not table or len(table) < 2:
            continue
        headers = table[0]
        for row in table[1:]:
            row_text = ", ".join(
                f"{headers[i]}: {cell.strip() if cell else ''}" 
                for i, cell in enumerate(row) if i < len(headers)
            )
            flat.append(row_text)
    
    return "\n".join(flat)

# %%
df["tables_text"] = df["tables"].apply(flatten_tables_verbose)

# %%
df["tables_text"] = df["tables_text"].str.replace('\n', ' ', regex=False)

# %%
# Out:
#                              pdf_file  page_number  \
# 0                        handbook.pdf            1
# 1                        handbook.pdf            2
# 2                        handbook.pdf            3
# 3                        handbook.pdf            4
# 4                        handbook.pdf            5
# ..                                ...          ...
# 358  hbi-2025-multi-faculty-depts.pdf           20
# 359  hbi-2025-multi-faculty-depts.pdf           21
# 360  hbi-2025-multi-faculty-depts.pdf           22
# 361  hbi-2025-multi-faculty-depts.pdf           23
# 362  hbi-2025-multi-faculty-depts.pdf           24
#
#                                                   text  \
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025\nHo...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025\nVi...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025\nPA...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025\nOF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025\nTA...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
#                                                 tables  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 358  [[[Choice Based Physics Course + Practical, Ob...
# 359  [[[Course, Seats, Duration, Eligibility*, Admi...
# 360  [[[Semester-I, Semester-II], [English-I, Engli...
# 361  [[[Paper IV & V-\n(a) Information Technology A...
# 362  [[[, , , Panjab University Chandigarh as equiv...
#
#                                           cleaned_text  \
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025 Hon...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025 Vic...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025 PAN...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025 OFF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025 TAB...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
#                                            tables_text
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 358  Choice Based Physics Course + Practical: Works...
# 359  Course: B.A.LL.B (Hons.) 5Years Integrated Cou...
# 360  Semester-I: English-I, Semester-II: English-II...
# 361  Paper IV & V- (a) Information Technology Act &...
# 362  : PGDCA, : 30, : 1 year, Panjab University Cha...
#
# [363 rows x 6 columns]

# %%
def chunk_text_token_based(text, tokenizer, max_tokens=512, stride=50):
    tokens = tokenizer.encode(text, add_special_tokens=False, truncation=False)
    chunks = []
    start = 0
    while start < len(tokens):
        end = start + max_tokens
        chunk_tokens = tokens[start:end]
        chunk = tokenizer.decode(chunk_tokens, skip_special_tokens=True)
        chunks.append(chunk)
        start += max_tokens - stride  # shift start index
    return chunks

# %%
df['chunks'] = df['cleaned_text'].apply(lambda x: chunk_text_token_based(x, tokenizer))

# %%
df['chunks_table'] = df['tables_text'].apply(lambda x: chunk_text_token_based(x, tokenizer))

# %%
df
# Out:
#                              pdf_file  page_number  \
# 0                        handbook.pdf            1
# 1                        handbook.pdf            2
# 2                        handbook.pdf            3
# 3                        handbook.pdf            4
# 4                        handbook.pdf            5
# ..                                ...          ...
# 358  hbi-2025-multi-faculty-depts.pdf           20
# 359  hbi-2025-multi-faculty-depts.pdf           21
# 360  hbi-2025-multi-faculty-depts.pdf           22
# 361  hbi-2025-multi-faculty-depts.pdf           23
# 362  hbi-2025-multi-faculty-depts.pdf           24
#
#                                                   text  \
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025\nHo...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025\nVi...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025\nPA...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025\nOF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025\nTA...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
#                                                 tables  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 358  [[[Choice Based Physics Course + Practical, Ob...
# 359  [[[Course, Seats, Duration, Eligibility*, Admi...
# 360  [[[Semester-I, Semester-II], [English-I, Engli...
# 361  [[[Paper IV & V-\n(a) Information Technology A...
# 362  [[[, , , Panjab University Chandigarh as equiv...
#
#                                           cleaned_text  \
# 0    FRONT PAGES 1 HANDBOOK OF INFORMATION 2025 Hon...
# 1    FRONT PAGES 2 HANDBOOK OF INFORMATION 2025 Vic...
# 2    FRONT PAGES 3 HANDBOOK OF INFORMATION 2025 PAN...
# 3    FRONT PAGES 4 HANDBOOK OF INFORMATION 2025 OFF...
# 4    FRONT PAGES 5 HANDBOOK OF INFORMATION 2025 TAB...
# ..                                                 ...
# 358  MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INFO...
# 359  MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INFO...
# 360  MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INFO...
# 361  MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INFO...
# 362  MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INFO...
#
#                                            tables_text  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 358  Choice Based Physics Course + Practical: Works...
# 359  Course: B.A.LL.B (Hons.) 5Years Integrated Cou...
# 360  Semester-I: English-I, Semester-II: English-II...
# 361  Paper IV & V- (a) Information Technology Act &...
# 362  : PGDCA, : 30, : 1 year, Panjab University Cha...
#
#                                                 chunks  \
# 0    [FRONT PAGES 1 HANDBOOK OF INFORMATION 2025 Ho...
# 1    [FRONT PAGES 2 HANDBOOK OF INFORMATION 2025 Vi...
# 2    [FRONT PAGES 3 HANDBOOK OF INFORMATION 2025 PA...
# 3    [FRONT PAGES 4 HANDBOOK OF INFORMATION 2025 OF...
# 4    [FRONT PAGES 5 HANDBOOK OF INFORMATION 2025 TA...
# ..                                                 ...
# 358  [MULTI FACULTY DEPARTMENTS 185 HANDBOOK OF INF...
# 359  [MULTI FACULTY DEPARTMENTS 186 HANDBOOK OF INF...
# 360  [MULTI FACULTY DEPARTMENTS 187 HANDBOOK OF INF...
# 361  [MULTI FACULTY DEPARTMENTS 188 HANDBOOK OF INF...
# 362  [MULTI FACULTY DEPARTMENTS 189 HANDBOOK OF INF...
#
#                                           chunks_table
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 358  [Choice Based Physics Course + Practical: Work...
# 359  [Course: B.A.LL.B (Hons.) 5Years Integrated Co...
# 360  [Semester-I: English-I, Semester-II: English-I...
# 361  [Paper IV & V- (a) Information Technology Act ...
# 362  [: PGDCA, : 30, : 1 year, Panjab University Ch...
#
# [363 rows x 8 columns]

# %%
from llama_index.core import Document

documents = []

for idx, row in df.iterrows():
    # Process text chunks
    for i, chunk in enumerate(row['chunks']):
        documents.append(Document(
            text=chunk,
            metadata={
                "source": row["pdf_file"],
                "chunk_type": "text",
                "chunk_id": f"text_{i}"
            }
        ))
    
    # Process table chunks
    for j, chunk in enumerate(row['chunks_table']):
        documents.append(Document(
            text=chunk,
            metadata={
                "source": row["pdf_file"],
                "chunk_type": "table",
                "chunk_id": f"table_{j}"
            }
        ))

# %%
len(documents)
# Out:
# 2424

# %%
from llama_index.core import Document, VectorStoreIndex, StorageContext
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core.node_parser import SimpleNodeParser
from llama_index.core.schema import TextNode
from chromadb import PersistentClient
from tqdm import tqdm

# Step 1: Create embedding model
embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Step 2: Setup Chroma vector store
persist_dir = "./chroma_db2"
client = PersistentClient(path=persist_dir)
collection = client.get_or_create_collection("rag-collection")
vector_store = ChromaVectorStore(chroma_collection=collection, persist_dir=persist_dir)

# Step 3: Create storage context
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# Step 4: Convert your DataFrame to Document list (text + table chunks)
documents = []

for idx, row in tqdm(df.iterrows(), total=len(df), desc="📄 Creating documents"):
    # Text chunks
    for i, chunk in enumerate(row['chunks']):
        documents.append(Document(
            text=chunk,
            metadata={
                "source": row["pdf_file"],
                "chunk_type": "text",
                "chunk_id": f"text_{i}"
            }
        ))
    # Table chunks
    for j, chunk in enumerate(row['chunks_table']):
        documents.append(Document(
            text=chunk,
            metadata={
                "source": row["pdf_file"],
                "chunk_type": "table",
                "chunk_id": f"table_{j}"
            }
        ))

# Step 5: Parse documents to nodes
parser = SimpleNodeParser()
nodes = []
for doc in tqdm(documents, desc="📄 Parsing documents"):
    nodes.extend(parser.get_nodes_from_documents([doc]))

# Step 6: Embed each node (with progress bar)
for node in tqdm(nodes, desc="🔍 Embedding nodes"):
    node.embedding = embed_model.get_text_embedding(node.text)
# Out:
# WARNING:tensorflow:From C:\Users\Hari\RAG-BOT\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# 📄 Creating documents: 100%|███████████████████████████████████████████████████████| 363/363 [00:00<00:00, 3213.56it/s]
# 📄 Parsing documents: 100%|███████████████████████████████████████████████████████| 2424/2424 [00:02<00:00, 970.85it/s]
# 🔍 Embedding nodes: 100%|██████████████████████████████████████████████████████████| 2424/2424 [02:40<00:00, 15.11it/s]

# %%
# Step 7: Build and persist the index
index = VectorStoreIndex(
    nodes,
    storage_context=storage_context,
    embed_model=embed_model
)
index.storage_context.persist(persist_dir="./index2")
